# %%
import soundfile as sf

# Load the file (no need to read all samples yet)
info = sf.info(r"OZOaN_5ymrc_48k.wav")
print(info)
# Out:
# OZOaN_5ymrc_48k.wav
# samplerate: 48000 Hz
# channels: 2
# duration: 25.045 s
# format: WAV (Microsoft) [WAV]
# subtype: Signed 16 bit PCM [PCM_16]
