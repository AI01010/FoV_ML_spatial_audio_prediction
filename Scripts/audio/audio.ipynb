# %%
import soundfile as sf

# Load the file (no need to read all samples yet)
info = sf.info(r"01-park-6eLyo2Y7mZU.wav")
print(info)
# Out:
# 01-park-6eLyo2Y7mZU.wav
# samplerate: 44100 Hz
# channels: 2
# duration: 01:7.046 min
# format: WAV (Microsoft) [WAV]
# subtype: Signed 16 bit PCM [PCM_16]
