# %%
vid_id = "0003"
startingFrame = 2000

# !rm -rf /content/Hani-Raft-Repo
# !rm -rf FoV_ML_spatial_audio_prediction
# !git clone --recurse-submodules https://github.com/AI01010/FoV_ML_spatial_audio_prediction.git

import os
os.chdir("FoV_ML_spatial_audio_prediction/Scripts/finalCode")
# !git pull origin main
# Out:
# Cloning into 'FoV_ML_spatial_audio_prediction'...
# remote: Enumerating objects: 1222, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 1222 (delta 58), reused 49 (delta 28), pack-reused 1111 (from 2)
# Receiving objects: 100% (1222/1222), 1.54 GiB | 33.55 MiB/s, done.
# Resolving deltas: 100% (498/498), done.
# Updating files: 100% (611/611), done.
# Filtering content: 100% (4/4), 70.06 MiB | 42.05 MiB/s, done.
# Submodule 'Hani-Raft-Repo' (https://github.com/HaniKamran/RAFT) registered for path 'Hani-Raft-Repo'
# Submodule 'U-2-Net-Repo' (https://github.com/xuebinqin/U-2-Net) registered for path 'U-2-Net-Repo'
# Cloning into '/content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Hani-Raft-Repo'...
# remote: Enumerating objects: 179, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 179 (delta 18), reused 0 (delta 0), pack-reused 148 (from 3)
# Receiving objects: 100% (179/179), 10.03 MiB | 24.93 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# Cloning into '/content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/U-2-Net-Repo'...
# remote: Enumerating objects: 1077, done.
# remote: Counting objects: 100% (422/422), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 1077 (delta 398), reused 380 (delta 380), pack-reused 655 (from 2)
# Receiving objects: 100% (1077/1077), 66.95 MiB | 39.56 MiB/s, done.
# Resolving deltas: 100% (539/539), done.
# Submodule path 'Hani-Raft-Repo': checked out '2888e15a51fa41140771d3f498ed8023cff098d1'
# Submodule path 'U-2-Net-Repo': checked out 'ac7e1c817ecab7c7dff5ce6b1abba61cd213ff29'
# From https://github.com/AI01010/FoV_ML_spatial_audio_prediction
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !jupyter nbconvert --to script getVideoData.ipynb
# !python getVideoData.py
# Out:
# [NbConvertApp] Converting notebook getVideoData.ipynb to script
# [NbConvertApp] Writing 8035 bytes to getVideoData.py
# Repo path was: /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo
# Using device: cuda
# U2 Net Model ready!
# Successfully imported core RAFT modules from your fork.
# Loading RAFT cuda model...
# RAFT model loaded on cuda successfully.
# Starting at frame 2000!
# Loading ambisonic audio...
# Audio shape: (2880000, 4)
# Audio sample rate: 48000 Hz
# Successfully loaded 4-channel first-order ambisonics audio
# Opening video...
# Video FPS: 60.0
# Total frames: 1000
# Video dimensions: 3840x1920
# Video will be resized from 3840x1920 to 1920x960
# Precomputing integrals for 20° tiles...
# Integral precomputation complete!
# Reading CSV file: Data/Pre-Processed-Data/head_data/head_video_0003.csv
# Output array shape: (199, 9, 960, 1920)
# Processing 199 frames...
# Processing frame 2005/1000 (sample 0/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /usr/local/lib/python3.12/dist-packages/torch/functional.py:505: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4317.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2010/1000 (sample 1/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2015/1000 (sample 2/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2020/1000 (sample 3/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2025/1000 (sample 4/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2030/1000 (sample 5/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2035/1000 (sample 6/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2040/1000 (sample 7/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2045/1000 (sample 8/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2050/1000 (sample 9/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2055/1000 (sample 10/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2060/1000 (sample 11/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2065/1000 (sample 12/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2070/1000 (sample 13/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2075/1000 (sample 14/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2080/1000 (sample 15/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2085/1000 (sample 16/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2090/1000 (sample 17/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2095/1000 (sample 18/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2100/1000 (sample 19/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2105/1000 (sample 20/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2110/1000 (sample 21/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2115/1000 (sample 22/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2120/1000 (sample 23/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2125/1000 (sample 24/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2130/1000 (sample 25/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2135/1000 (sample 26/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2140/1000 (sample 27/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2145/1000 (sample 28/199)
# ...
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2955/1000 (sample 190/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2960/1000 (sample 191/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2965/1000 (sample 192/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2970/1000 (sample 193/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2975/1000 (sample 194/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2980/1000 (sample 195/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2985/1000 (sample 196/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2990/1000 (sample 197/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
# Processing frame 2995/1000 (sample 198/199)
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../U-2-Net-Repo/model/u2net.py:23: UserWarning: `nn.functional.upsample` is deprecated. Use `nn.functional.interpolate` instead.
#   src = F.upsample(src,size=tar.shape[2:],mode='bilinear')
#
# Trying scale 1.0...
# Padded tensor shapes: t1=torch.Size([1, 3, 960, 1920]), t2=torch.Size([1, 3, 960, 1920])
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:99: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:110: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# /content/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/FoV_ML_spatial_audio_prediction/Scripts/finalCode/../../Hani-Raft-Repo/core/raft.py:127: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=self.args.mixed_precision):
# ✓ Flow computed successfully at scale 1.0
#
# Generated 199 tile indices
# Tile index range: 77 to 77
# Saving output to FinalTrainingData/0003_2000_heatmaps.npy...
# Done! Output shape: (199, 9, 960, 1920)
# Saved to: FinalTrainingData/0003_2000_labels.npy
# Saving output to FinalTrainingData/0003_2000_heatmaps.npy...
# Done! Output shape: (199, 9, 960, 1920)
# Saved to: FinalTrainingData/0003_2000_heatmaps.npy

# %%
from google.colab import files
files.download(f"../../FinalTrainingData/{vid_id}_{startingFrame}_labels.npy")

from google.colab import drive
drive.mount('/content/drive')

import os

save_dir = '/content/drive/MyDrive/FinalTrainingData'
os.makedirs(save_dir, exist_ok=True)

import shutil
drive_file = os.path.join(save_dir, f"{vid_id}_{startingFrame}_heatmaps.npy")
local_file = f"../../FinalTrainingData/{vid_id}_{startingFrame}_heatmaps.npy"

shutil.copy(local_file, drive_file)

if os.path.exists(drive_file):
    print(f"✅ File exists in Drive: {drive_file}")
else:
    print(f"❌ File not found: {drive_file}")

drive.flush_and_unmount()  # flush any pending writes
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ File exists in Drive: /content/drive/MyDrive/FinalTrainingData/0003_2000_heatmaps.npy
# Mounted at /content/drive
